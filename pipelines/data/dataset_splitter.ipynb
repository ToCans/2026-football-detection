# %% [markdown]
# #### Imports

# %%
# Imports
import os
import sys

# %% [markdown]
# #### Path Configurations

# %%
# Get the absolute path to the 'project' directory
project_root = os.path.abspath(os.path.join('..', '..'))

# Add it to sys.path if it's not already there
if project_root not in sys.path:
    sys.path.append(project_root)

# Path Configuration
data_directory = os.path.join(project_root, "data")
data_to_split_directory = os.path.join(data_directory, "detection" , "2000_soccernet_tracking")

# %% [markdown]
# #### Utils Imports

# %%
from utils.data import split_dataset

# %% [markdown]
# #### Splitting Dataset

# %%
split_dataset(data_to_split_directory, data_to_split_directory, train_ratio=0.75, val_ratio=0.15, test_ratio=0.1)
# Out:
# Dataset split complete (2000 pairs):
#   train : 1500
#   valid : 300
#   test  : 200
# {'train': 1500, 'valid': 300, 'test': 200, 'skipped': 0}
