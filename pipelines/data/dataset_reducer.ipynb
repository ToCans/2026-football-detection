# %% [markdown]
# #### Imports

# %%
# Imports
import os
import sys

# %% [markdown]
# #### Path Configurations

# %%
# Get the absolute path to the 'project' directory
project_root = os.path.abspath(os.path.join('..', '..'))

# Add it to sys.path if it's not already there
if project_root not in sys.path:
    sys.path.append(project_root)

# Path Configuration
keep_percentage = 0.05
data_directory = os.path.join(project_root, "data")
data_to_reduce_directory = os.path.join(data_directory, "detection" , "soccernet_tracking_no_challenge")
data_subset_directory = os.path.join(data_directory, "detection" , f"{str(keep_percentage).replace(".","p")}_soccernet_tracking_no_challenge")

# %% [markdown]
# #### Utils Imports

# %%
from utils.data import create_yolo_subset_dataset

# %% [markdown]
# #### Reducing Dataset

# %%
create_yolo_subset_dataset(data_to_reduce_directory, data_subset_directory, keep_percentage)
# Out:
# Processing train: Keeping 1837 of 36750 images.
# Processing valid: Keeping 300 of 6000 images.
# Processing test: Keeping 1837 of 36750 images.
# Copied data.yaml to new root.
